# %%
from stage_1 import run_stage_1
from stage_2 import run_stage_2
from stage_3 import run_stage_3_a, run_stage_3_b
from stage_4 import run_stage_4, CarbonSenseStage4Config

# %%
'''
Stage 1 is preprocessing. It starts with a collection of source datasets, and organizes
them by site. So the output directory will have a single subdirectory for every site,
possibly with multiple CSVs per site if they're present in multiple source datasets.

It also handles some preliminary column processing such as timestamp harmonization and
setting null values to NaN.

Every source dataset requires a preprocessing class in the Stage 1 file.
'''
run_stage_1('data')
# Out:
# Preprocessing initiated for ameriflux...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 11
#       1 '''
#       2 Stage 1 is preprocessing. It starts with a collection of source datasets, and organizes
#       3 them by site. So the output directory will have a single subdirectory for every site,
#    (...)      9 Every source dataset requires a preprocessing class in the Stage 1 file.
#      10 '''
# ---> 11 run_stage_1('data')
#
# File ~/Developer/Stage_S25/era5_workbench/CarbonSense/stage_1.py:143, in run_stage_1(data_dir)
#     141 for source_name, preprocessor in REGISTER:
#     142     print(f'Preprocessing initiated for {source_name}...')
# --> 143     preprocessor(data_dir, source_name).process()
#
# File ~/Developer/Stage_S25/era5_workbench/CarbonSense/stage_1.py:36, in AmerifluxPreprocessor.process(self)
#      33     return 'FLUXNET_SUBSET_HH' in filename and 'VARINFO' not in filename
#      35 os.makedirs(output_dir, exist_ok=True)
# ---> 36 shutil.copy(input_dir / 'site_data.csv', output_dir / 'site_data.csv')
#      37 for site in tqdm(os.listdir(input_dir / 'unzipped')):
#      38     site_dir = input_dir / 'unzipped' / site
#
# File /opt/anaconda3/envs/carbonsense/lib/python3.12/shutil.py:435, in copy(src, dst, follow_symlinks)
#     433 if os.path.isdir(dst):
#     434     dst = os.path.join(dst, os.path.basename(src))
# --> 435 copyfile(src, dst, follow_symlinks=follow_symlinks)
#     436 copymode(src, dst, follow_symlinks=follow_symlinks)
#     437 return dst
#
# File /opt/anaconda3/envs/carbonsense/lib/python3.12/shutil.py:260, in copyfile(src, dst, follow_symlinks)
#     258     os.symlink(os.readlink(src), dst)
#     259 else:
# --> 260     with open(src, 'rb') as fsrc:
#     261         try:
#     262             with open(dst, 'wb') as fdst:
#     263                 # macOS
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/raw/ameriflux/site_data.csv'

# %%
'''

'''
run_stage_2('data')
# Out:
# Parsing and reducing column space...
#   Processing fluxnet...
# 100%|██████████| 195/195 [08:34<00:00,  2.64s/it]
#   Processing ameriflux...
# 100%|██████████| 192/192 [08:45<00:00,  2.73s/it]
#   Processing icos-2023...
# 100%|██████████| 58/58 [02:08<00:00,  2.22s/it]
#   Processing icos-ww...
# 100%|██████████| 73/73 [08:15<00:00,  6.79s/it]
#   Processing fluxnet-ch4...
# 100%|██████████| 79/79 [01:46<00:00,  1.35s/it]
# Writing metadata and audit logs...
# 100%|██████████| 417/417 [00:00<00:00, 6728.44it/s]
# Merging site data from disparate releases...
# 100%|██████████| 417/417 [23:09<00:00,  3.33s/it]

# %%
#run_stage_3_a('data', download_phenocam=True)
run_stage_3_b('data')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 #run_stage_3_a('data', download_phenocam=True)
# ----> 2 run_stage_3_b('data')
#
# NameError: name 'run_stage_3_b' is not defined

# %%
run_stage_4('data', config=CarbonSenseStage4Config(aggregation="hourly"))
# Out:
# Preparing site data for SQL...
# 100%|██████████| 417/417 [08:22<00:00,  1.20s/it]
